# %%
include("grape.jl")
using Ipopt
using NLopt
using PyPlot
# Out:
# WARNING: using NLopt.optimize! in module Main conflicts with an existing identifier.

# %%
const target_pi = SA[0im 1.0; 1.0 0im]
const scales_1 = ((1.0, 1.0), (0.9, 0.9), (0.8, 0.8), (0.7, 0.7))
# Out:
# ((1.0, 1.0), (0.9, 0.9), (0.8, 0.8), (0.7, 0.7))

# %%
opt_pi4_1 = SingleBitOptimizer(target_pi, scales_1, 4)
model_pi4_1 = Model(Ipopt.Optimizer)
params_pi4_1 = prep_model(opt_pi4_1, model_pi4_1)
optimize!(opt_pi4_1, model_pi4_1, params_pi4_1, fill(0.2, 10))
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       10
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       10
#                      variables with only upper bounds:        0
# ...

# %%
opt_pi6_1 = SingleBitOptimizer(target_pi, scales_1, 6)
# model_pi6_1 = Model(Ipopt.Optimizer)
# set_optimizer_attribute(model_pi6_1, "print_level", 0)
model_pi6_1 = Model(NLopt.Optimizer)
# set_optimizer_attribute(model_pi6_1, "algorithm", :LD_LBFGS)
# set_optimizer_attribute(model_pi6_1, "algorithm", :LD_MMA)
set_optimizer_attribute(model_pi6_1, "algorithm", :LN_COBYLA)
params_pi6_1 = prep_model(opt_pi6_1, model_pi6_1)
optimize!(opt_pi6_1, model_pi6_1, params_pi6_1, [-1.5244318600501652, 7.46551333132321, 6.130352489039963, 3.5951941512812606, 3.8055410891557546, 3.765027985420797, -0.8317556592170681, 7.78478732900251, -3.8956153751871447, 4.346329353689089, 1.7367570729444939, 7.192232017447304, -3.1630890367760145, -1.5707963637862452])
# Out:
# ([-3.046192014120447, 7.311248984464126, 6.116902114385961, 3.654203795520446, 4.481271236088173, 3.6574411151514914, 0.15277518549822447, 7.310234270553591, -2.8118256961303776, 3.652274065017742, 4.196926659554546, 7.314549218612556, -2.353032235999761, -1.5707964682120388], 2.818462595106381e-7)

# %%
opt_pi3_1 = SingleBitOptimizer(target_pi, scales_1, 3)
model_pi3_1 = Model(Ipopt.Optimizer)
params_pi3_1 = prep_model(opt_pi3_1, model_pi3_1)
optimize!(opt_pi3_1, model_pi3_1, params_pi3_1, fill(0.45, 8))
# Out:
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...

# %%
opt_pi3_1 = SingleBitOptimizer(target_pi, scales_1, 3)
model_pi3_1 = Model(Ipopt.Optimizer)
params_pi3_1 = prep_model(opt_pi3_1, model_pi3_1)
optimize!(opt_pi3_1, model_pi3_1, params_pi3_1, [0.0, 1π * 1.1, 1.8234765819369754, 2π * 1.1, -1.8234765819369754, 2π * 1.1, 0.0, -π/2])
# Out:
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...

# %%
opt_pi3_1 = SingleBitOptimizer(target_pi, scales_1, 3)
model_pi3_1 = Model(Ipopt.Optimizer)
params_pi3_1 = prep_model(opt_pi3_1, model_pi3_1)
optimize!(opt_pi3_1, model_pi3_1, params_pi3_1, [0.0, 1π * 1.1, 2.0943951023931957, π * 1.1, 0.0, π * 1.1, 0.0, -π/2])
# Out:
# This is Ipopt version 3.14.16, running with linear solver MUMPS 5.7.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...
