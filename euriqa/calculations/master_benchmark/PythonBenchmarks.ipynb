# %%
import numpy as np
import qt

# %%
print("n=10")
p = qt.motion_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 10)
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2001))
p = qt.motion2_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 10)
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2001))
print("n=50")
p = qt.motion_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 50)
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2001))
p = qt.motion2_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 50)
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2001))
print("n=250")
p = qt.motion_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 250)
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion(p, np.linspace(0, 4 / (2 * 0.13), 2001))
p = qt.motion2_problem(2 * np.pi * 0.13, 2 * np.pi * 0.032, 0.0, 0.0, 250)
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2))
# %timeit qt.solve_motion2(p, np.linspace(0, 4 / (2 * 0.13), 2001))
# Out:
# n=10
# 3.5 ms ± 7.18 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25 ms ± 53.8 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.48 ms ± 3.76 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 26.7 ms ± 90.7 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# n=50
# 321 ms ± 944 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 462 ms ± 432 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 320 ms ± 450 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 462 ms ± 326 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# n=250
# 36.1 s ± 36.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 39.2 s ± 16.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 36.2 s ± 146 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 39.3 s ± 22 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
