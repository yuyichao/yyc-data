# %%
using BenchmarkTools

# %%
include("qt.jl")
include("qo.jl")
include("simple.jl")
include("opt.jl")
# Out:
# Main.OPTTest

# %%
function test_motion(M)
    println(M)
    println("n=10")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 10)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 10)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    println("n=50")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 50)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 50)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    println("n=250")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 250)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 250)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    return
end
# Out:
# test_motion (generic function with 1 method)

# %%
test_motion(QTTest)
# Out:
# Main.QTTest
# n=10
#   2.275 ms (161 allocations: 752.37 KiB)
#   3.721 ms (8171 allocations: 13.31 MiB)
#   2.245 ms (161 allocations: 752.37 KiB)
#   3.698 ms (8171 allocations: 13.31 MiB)
# n=50
#   146.353 ms (164 allocations: 55.31 MiB)
#   181.597 ms (8174 allocations: 360.71 MiB)
#   145.645 ms (164 allocations: 55.31 MiB)
#   189.699 ms (8174 allocations: 360.71 MiB)
# n=250
#   21.721 s (173 allocations: 2.20 GiB)
#   27.879 s (8183 allocations: 9.65 GiB)
#   24.768 s (173 allocations: 2.20 GiB)
#   29.034 s (8183 allocations: 9.65 GiB)

# %%
test_motion(QOTest)
# Out:
# Main.QOTest
# n=10
#   2.542 ms (207 allocations: 140.16 KiB)
#   4.097 ms (8223 allocations: 12.86 MiB)
#   1.494 ms (203 allocations: 140.91 KiB)
#   3.057 ms (8219 allocations: 12.86 MiB)
# n=50
#   220.223 ms (208 allocations: 3.17 MiB)
#   264.722 ms (8224 allocations: 308.72 MiB)
#   106.041 ms (203 allocations: 3.21 MiB)
#   140.601 ms (8219 allocations: 308.76 MiB)
# n=250
#   19.519 s (209 allocations: 77.16 MiB)
#   22.895 s (8225 allocations: 7.52 GiB)
#   20.718 s (203 allocations: 80.12 MiB)
#   21.973 s (8219 allocations: 7.53 GiB)

# %%
test_motion(SimpleTest)
# Out:
# Main.SimpleTest
# n=10
#   1.485 ms (101 allocations: 110.68 KiB)
#   2.985 ms (6118 allocations: 12.59 MiB)
#   1.485 ms (101 allocations: 110.68 KiB)
#   2.994 ms (6118 allocations: 12.59 MiB)
# n=50
#   105.711 ms (101 allocations: 2.60 MiB)
#   136.637 ms (6118 allocations: 307.90 MiB)
#   105.883 ms (101 allocations: 2.60 MiB)
#   136.313 ms (6118 allocations: 307.90 MiB)
# n=250
#   25.925 s (101 allocations: 64.85 MiB)
#   30.612 s (6118 allocations: 7.51 GiB)
#   30.653 s (101 allocations: 64.85 MiB)
#   33.211 s (6118 allocations: 7.51 GiB)

# %%
test_motion(OPTTest)
# Out:
# Main.OPTTest
# n=10
#   896.371 μs (1010 allocations: 124.88 KiB)
#   2.450 ms (7027 allocations: 12.60 MiB)
#   895.829 μs (1010 allocations: 124.88 KiB)
#   2.448 ms (7027 allocations: 12.60 MiB)
# n=50
#   75.098 ms (776 allocations: 2.61 MiB)
#   92.040 ms (6793 allocations: 307.91 MiB)
#   59.508 ms (776 allocations: 2.61 MiB)
#   104.140 ms (6793 allocations: 307.91 MiB)
# n=250
#   16.309 s (1928 allocations: 64.88 MiB)
#   21.307 s (7945 allocations: 7.51 GiB)
#   15.683 s (1928 allocations: 64.88 MiB)
#   18.653 s (7945 allocations: 7.51 GiB)
