# %%
using BenchmarkTools

# %%
include("qt.jl")
include("qo.jl")
include("simple.jl")
include("opt.jl")
# Out:
# Main.OPTTest

# %%
function test_motion(M)
    println(M)
    println("n=10")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 10)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 10)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    println("n=50")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 50)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 50)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    println("n=250")
    p = M.motion_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 250)
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    p = M.motion2_problem(2π * 0.13, 2π * 0.032, 0.0, 0.0, 250)
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2)))
    @btime $(M.solve_motion2)($(p), $(range(0, 4 * π / (2π * 0.13), 2001)))
    return
end
# Out:
# test_motion (generic function with 1 method)

# %%
test_motion(QTTest)
# Out:
# Main.QTTest
# n=10
#   2.087 ms (161 allocations: 752.37 KiB)
#   3.247 ms (8171 allocations: 13.31 MiB)
#   2.056 ms (161 allocations: 752.37 KiB)
#   3.222 ms (8171 allocations: 13.31 MiB)
# n=50
#   131.454 ms (164 allocations: 55.31 MiB)
#   162.903 ms (8174 allocations: 360.71 MiB)
#   129.794 ms (164 allocations: 55.31 MiB)
#   158.844 ms (8174 allocations: 360.71 MiB)
# n=250
#   14.540 s (173 allocations: 2.20 GiB)
#   16.325 s (8183 allocations: 9.65 GiB)
#   14.757 s (173 allocations: 2.20 GiB)
#   16.073 s (8183 allocations: 9.65 GiB)

# %%
test_motion(QOTest)
# Out:
# Main.QOTest
# n=10
#   2.323 ms (207 allocations: 140.16 KiB)
#   3.585 ms (8223 allocations: 12.86 MiB)
#   1.368 ms (203 allocations: 140.91 KiB)
#   2.612 ms (8219 allocations: 12.86 MiB)
# n=50
#   166.197 ms (208 allocations: 3.17 MiB)
#   195.566 ms (8224 allocations: 308.72 MiB)
#   96.734 ms (203 allocations: 3.21 MiB)
#   125.794 ms (8219 allocations: 308.76 MiB)
# n=250
#   11.873 s (209 allocations: 77.16 MiB)
#   13.270 s (8225 allocations: 7.52 GiB)
#   3.241 s (203 allocations: 80.12 MiB)
#   4.918 s (8219 allocations: 7.53 GiB)

# %%
test_motion(SimpleTest)
# Out:
# Main.SimpleTest
# n=10
#   1.361 ms (101 allocations: 110.68 KiB)
#   2.566 ms (6118 allocations: 12.59 MiB)
#   1.359 ms (101 allocations: 110.68 KiB)
#   2.560 ms (6118 allocations: 12.59 MiB)
# n=50
#   96.643 ms (101 allocations: 2.60 MiB)
#   125.084 ms (6118 allocations: 307.90 MiB)
#   96.614 ms (101 allocations: 2.60 MiB)
#   124.217 ms (6118 allocations: 307.90 MiB)
# n=250
#   4.819 s (101 allocations: 64.85 MiB)
#   6.547 s (6118 allocations: 7.51 GiB)
#   4.806 s (101 allocations: 64.85 MiB)
#   6.448 s (6118 allocations: 7.51 GiB)

# %%
test_motion(OPTTest)
# Out:
# Main.OPTTest
# n=10
#   816.458 μs (101 allocations: 110.68 KiB)
#   2.036 ms (6118 allocations: 12.59 MiB)
#   815.708 μs (101 allocations: 110.68 KiB)
#   2.018 ms (6118 allocations: 12.59 MiB)
# n=50
#   51.680 ms (101 allocations: 2.60 MiB)
#   79.432 ms (6118 allocations: 307.90 MiB)
#   51.690 ms (101 allocations: 2.60 MiB)
#   79.076 ms (6118 allocations: 307.90 MiB)
# n=250
#   2.750 s (101 allocations: 64.85 MiB)
#   5.028 s (6118 allocations: 7.51 GiB)
#   2.801 s (101 allocations: 64.85 MiB)
#   4.831 s (6118 allocations: 7.51 GiB)
